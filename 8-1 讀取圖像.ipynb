# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img=mpimg.imread('d:/ipython/picture/Penguin.jpg')

# %%
print(img.shape)
# Out:
# (1075, 864, 3)

# %%
plt.imshow(img)

# %%
# picture
# zh.wikipedia.org/wiki/國王企鵝
